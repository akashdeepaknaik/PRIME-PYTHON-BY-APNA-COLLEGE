# %% [markdown]
# # Day - 01 [Prime Ai/Ml Batch Apna College] - Lec 02

# %% [markdown]
# ### Variable in Python

# %% [markdown]
# #### Variable is the name of the memory location which stores some data

# %%
name = "Akash"
age = 23
print("My name is",name,"and i am",age,"years old!")
# Out:
# My name is Akash and i am 23 years old!

# %% [markdown]
# #### Indentation is very important in python
# #### Here name , age is called as a identifiers and these are case sensitive
