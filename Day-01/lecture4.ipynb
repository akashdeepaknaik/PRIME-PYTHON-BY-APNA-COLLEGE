# %% [markdown]
# # Day 01 [Prime Batch AI/ML By Apna College] Lecture - 04

# %% [markdown]
# ## Keywords
# ### Keywords are the resereved words that have special meaning to the compiler
# ### There are 35 Keywords are there in python

# %%
import keyword
count=0
for i in keyword.kwlist:
   count+=1
print(count)
# Out:
# 35

# %%
# Syntax to print all kwywords in python
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## Comments
# ### There are two types of comments are there in python
# ### 1. Single Line Comment
# ### 2. Myltiline comments

# %%
#We can write any comment to write we have to add # before any statement
print("Hello") #This line prints the hello as it is on the output
# Out:
# Hello

# %% [markdown]
# #### '''
# #### Hello This was
# #### my Multiline comment
# #### '''
