# %% [markdown]
# # Day - 01 [Prime Ai/Ml Batch Apna College] - Lec 03

# %% [markdown]
# #### Data Types

# %% [markdown]
# #### 1. Integer

# %%
age = 23
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# #### 2. Float

# %%
pi = 3.14
print(type(pi))
# Out:
# <class 'float'>

# %% [markdown]
# #### 3. String

# %%
Fname = "Akash"
Mname = 'Deepak'
Lname = '''Naik'''
print(type(Fname))
print(type(Fname))
print(type(Fname))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# #### 4. Boolean

# %%
isFollow = True
print(type(isFollow))
# Out:
# <class 'bool'>

# %%
isBlock = False
print(type(isBlock))
# Out:
# <class 'bool'>

# %%
isPrime = True
print(isPrime)
# Out:
# True

# %%
isNotPrime = False
print(isNotPrime)
# Out:
# False

# %% [markdown]
# #### 5. None

# %% [markdown]
# #### If we don't want to assign any value to a variable then we assign that variable value as a none

# %%
blankVar = None
print(blankVar)
print(type(blankVar))
# Out:
# None
# <class 'NoneType'>
