# %% [markdown]
# # Day - 01 [Prime Ai/Ml Batch Apna College]

# %%
#Our First Program
print("Hello World!")

#Here print() is a function
#The logic of printing any statement was written in liraries files of python
#In print function if we write anything within the double quote the print()
#prints the statements as it is
# Out:
# Hello World!

# %%
print("Hey everyone welcome to my Repository!")
print("In this repo u can access my codes of Prime batch by apna Collge")
# Out:
# Hey everyone welcome to my Repository!
# In this repo u can access my codes of Prime batch by apna Collge

# %% [markdown]
# #### \n - Nextline

# %%
# \n command 
print("Hello \nAkash")

#If in our output we want to insert nextline at any point we can use these perticular character
# Out:
# Hello
# Akash

# %% [markdown]
# ## Character Set In Python

# %% [markdown]
# #### Letters : A - Z, a - z
# #### Digits  : 0 - 9
# #### Special Symbol : + , - , * , /, % etc
# #### Whitespaces : blank space , [ \t ] tab , [ \n ] newline etc
# #### all ASCII & UNICODE chars as part of data & literals
#
# #### These all are the allowed character set in python
